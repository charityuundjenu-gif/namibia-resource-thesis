# %% [markdown]
# # 04 — Sample Construction and Dataset Filtering
#
# This notebook constructs the analytical sample used in the thesis.
#
# Steps:
# 1. Restrict time period (2000–2021)
# 2. Identify oil-dependent countries
# 3. Apply data completeness criteria
# 4. Remove unstable growth outliers
# 5. Ensure Namibia inclusion
#
# Output:
# - final_analysis_dataset.csv
# - country_sample_list.csv

# %%
# =========================
# SETUP
# =========================

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_PATH = "/content/drive/MyDrive/thesis_project/"

PROCESSED_DATA = BASE_PATH + "data/processed/"
OUTPUT_DATA = BASE_PATH + "data/outputs/"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Master Panel Dataset

# %%
master = pd.read_csv(
    PROCESSED_DATA + "master_dataset.csv"
)

master.head()
# Out:
#   Country Name Country Code  Year  Oil_Rents_GDP  log_oil_rents  GDP_growth  \
# 0        Aruba          ABW  1985            NaN            NaN         NaN
# 1        Aruba          ABW  1986            0.0            0.0         NaN
# 2        Aruba          ABW  1987            0.0            0.0   16.078431
# 3        Aruba          ABW  1988            0.0            0.0   18.648649
# 4        Aruba          ABW  1989            0.0            0.0   12.129841
#
#    GDP_per_capita  log_gdp_per_capita  Inflation  Inflation_w  Gov_Debt_GDP  \
# 0             NaN                 NaN   4.032258     4.032258           NaN
# 1    16150.651073            9.689778   1.073966     1.073966           NaN
# 2    18992.068378            9.851829   3.643045     3.643045           NaN
# 3    22468.507120           10.019914   3.121868     3.121868           NaN
# 4    24730.396448           10.115829   3.991628     3.991628           NaN
#
#    log_debt  Control of Corruption  Government Effectiveness  Rule of Law
# 0       NaN                    NaN                       NaN          NaN
# 1       NaN                    NaN                       NaN          NaN
# 2       NaN                    NaN                       NaN          NaN
# 3       NaN                    NaN                       NaN          NaN
# 4       NaN                    NaN                       NaN          NaN

# %% [markdown]
# ## Dataset Overview

# %%
print("Countries:", master["Country Code"].nunique())
print("Years:", master["Year"].nunique())
print("Observations:", len(master))
# Out:
# Countries: 224
# Years: 65
# Observations: 12263

# %% [markdown]
# ## Restrict Analysis Period (2000–2021)

# %%
master = master[
    (master["Year"] >= 2000) &
    (master["Year"] <= 2021)
].copy()

master["Year"].describe()
# Out:
# count    4948.000000
# mean     2010.605699
# std         6.313130
# min      2000.000000
# 25%      2005.000000
# 50%      2011.000000
# 75%      2016.000000
# max      2021.000000
# Name: Year, dtype: float64

# %% [markdown]
# ## Identify Oil-Dependent Countries
# Countries with average oil rents ≥ 3% of GDP.

# %%
oil_mean = (
    master
    .groupby("Country Code")["Oil_Rents_GDP"]
    .mean()
    .reset_index(name="mean_oil_rents")
)

oil_countries = oil_mean[
    oil_mean["mean_oil_rents"] >= 3
]["Country Code"]

sample = master[
    master["Country Code"].isin(oil_countries)
].copy()

print("Countries after oil filter:",
      sample["Country Code"].nunique())
# Out:
# Countries after oil filter: 40

# %% [markdown]
# ## Data Completeness Filter
# Countries must have ≥75% data availability across core variables.

# %%
core_vars = [
    "Oil_Rents_GDP",
    "GDP_growth",
    "GDP_per_capita",
    "Inflation",
    "Gov_Debt_GDP",
    "Control of Corruption",
    "Government Effectiveness",
    "Rule of Law"
]

completeness = (
    sample
    .groupby("Country Code")[core_vars]
    .apply(lambda x: x.notna().mean().mean())
    .reset_index(name="completeness_ratio")
)

valid_countries = completeness[
    completeness["completeness_ratio"] >= 0.75
]["Country Code"]

sample = sample[
    sample["Country Code"].isin(valid_countries)
]

print("Countries after completeness filter:",
      sample["Country Code"].nunique())
# Out:
# Countries after completeness filter: 37

# %% [markdown]
# ## Remove Extreme Growth Volatility
# Median Absolute Deviation (MAD) filter.

# %%
def mad(x):
    return np.median(np.abs(x - np.median(x)))

growth_mad = (
    sample
    .groupby("Country Code")["GDP_growth"]
    .apply(mad)
    .reset_index(name="growth_mad")
)

median_mad = growth_mad["growth_mad"].median()

stable_countries = growth_mad[
    growth_mad["growth_mad"] <= 3 * median_mad
]["Country Code"]

sample = sample[
    sample["Country Code"].isin(stable_countries)
]

# %% [markdown]
# ## Ensure Namibia Inclusion
# Namibia is retained regardless of filtering outcomes.

# %%
namibia_data = master[master["Country Code"] == "NAM"]

sample = pd.concat([sample, namibia_data]).drop_duplicates()

sample[sample["Country Code"] == "NAM"].head()
# Out:
#      Country Name Country Code  Year  Oil_Rents_GDP  log_oil_rents  \
# 7791      Namibia          NAM  2000            0.0            0.0
# 7792      Namibia          NAM  2001            0.0            0.0
# 7793      Namibia          NAM  2002            0.0            0.0
# 7794      Namibia          NAM  2003            0.0            0.0
# 7795      Namibia          NAM  2004            0.0            0.0
#
#       GDP_growth  GDP_per_capita  log_gdp_per_capita  Inflation  Inflation_w  \
# 7791    3.492183     3083.596579            8.034176        NaN          NaN
# 7792    1.177949     3055.404448            8.024994        NaN          NaN
# 7793    4.788661     3145.945663            8.054188        NaN          NaN
# 7794    4.239794     3232.305897            8.081260   7.136153     7.136153
# 7795   12.269548     3582.895033            8.184205   4.136632     4.136632
#
#       Gov_Debt_GDP  log_debt  Control of Corruption  Government Effectiveness  \
# 7791           NaN       NaN               0.555990                  0.469873
# 7792           NaN       NaN                    NaN                       NaN
# 7793           NaN       NaN               0.100783                  0.139743
# 7794           NaN       NaN               0.064888                  0.168386
# 7795           NaN       NaN              -0.010850                  0.104889
#
#       Rule of Law
# 7791     0.445161
# 7792          NaN
# 7793     0.358799
# 7794     0.329183
# 7795     0.018302

# %% [markdown]
# ## Final Sample Overview

# %%
print("Final countries:",
      sample["Country Code"].nunique())
# Out:
# Final countries: 36

# %% [markdown]
# ## Create Country Sample List

# %%
final_countries = (
    sample[["Country Code","Country Name"]]
    .drop_duplicates()
    .sort_values("Country Name")
)

final_countries
# Out:
#       Country Code          Country Name
# 3172           DZA               Algeria
# 125            AGO                Angola
# 651            AZE            Azerbaijan
# 1080           BHR               Bahrain
# 1410           BOL               Bolivia
# 1595           BRN     Brunei Darussalam
# 2235           CMR              Cameroon
# 10731          TCD                  Chad
# 2448           COL              Colombia
# 2365           COG           Congo, Rep.
# 3237           ECU               Ecuador
# 3302           EGY      Egypt, Arab Rep.
# 3841           GAB                 Gabon
# 5198           IRN    Iran, Islamic Rep.
# 5263           IRQ                  Iraq
# 5692           KAZ            Kazakhstan
# 6069           KWT                Kuwait
# 6277           LBY                 Libya
# 7746           MYS              Malaysia
# 7045           MEX                Mexico
# 7791           NAM               Namibia
# 7980           NGA               Nigeria
# 8189           NOR                Norway
# 8439           OMN                  Oman
# 8819           PNG      Papua New Guinea
# 9305           QAT                 Qatar
# 9401           RUS    Russian Federation
# 9531           SAU          Saudi Arabia
# 9596           SDN                 Sudan
# 10290          SUR              Suriname
# 10642          SYR  Syrian Arab Republic
# 10974          TLS           Timor-Leste
# 11088          TTO   Trinidad and Tobago
# 11152          TUN               Tunisia
# 315            ARE  United Arab Emirates
# 11873          VNM              Viet Nam

# %% [markdown]
# ## Save Analytical Dataset

# %%
sample = sample.sort_values(
    ["Country Code", "Year"]
).reset_index(drop=True)

# %%
sample.to_csv(
    OUTPUT_DATA + "final_analysis_dataset.csv",
    index=False,
    float_format="%.10f"
)

final_countries.to_csv(
    OUTPUT_DATA + "country_sample_list.csv",
    index=False
)

# %% [markdown]
# ## Pipeline Completion

# %%
print("✅ Final analytical dataset created.")
# Out:
# ✅ Final analytical dataset created.
